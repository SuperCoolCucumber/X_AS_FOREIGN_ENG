# %%
import pandas as pd
from pathlib import Path
import zipfile

# %%
# text = '/home/daria/Downloads/REALEC_texts.zip'
# preds = '/home/daria/Downloads/REALEC_predictions.csv'

# insert your path to the files

# %%
with zipfile.ZipFile(text) as file:
  file.extractall('files')

# %%
files = list(Path('files').iterdir())

# %%
def read_text(path):
    with open(path) as file:
        txt = file.readlines()
    return txt, path.name

# %%
txt = {name: ' '.join(txt) for txt, name in map(read_text, files)}

# %%
levels = pd.read_csv(preds, index_col=0)

# %%
levels
# Out:
#               der_level3  der_level4  der_level5  der_level6   mci  \
# name
# AAl_1_1.txt     0.022727    0.045455    0.022727    0.181818  4.75
# AAl_1_2.txt     0.044444    0.122222    0.100000    0.044444  3.00
# AAl_11_2.txt    0.030303    0.040404    0.070707    0.121212  4.00
# AAl_12_1.txt    0.045455    0.075758    0.015152    0.045455  6.50
# AAl_12_2.txt    0.068966    0.172414    0.126437    0.068966  4.50
# ...                  ...         ...         ...         ...   ...
# VPe_35_1.txt    0.048780    0.024390    0.000000    0.073171  3.75
# VPe_35_2.txt    0.021739    0.173913    0.032609    0.032609  1.75
# VPe_36_1.txt    0.000000    0.083333    0.041667    0.020833  6.00
# AAl_14_2.txt    0.034091    0.056818    0.045455    0.068182  3.75
# KKo_24_1.txt    0.000000    0.079365    0.063492    0.015873  4.25
#
#               num_gerunds   density        ls        vs  corrected_vs  ...  \
# name                                                                   ...
# AAl_1_1.txt             2  0.466368  0.269231  0.000000      0.000000  ...
# AAl_1_2.txt             1  0.495549  0.125749  0.062500      0.250000  ...
# AAl_11_2.txt            5  0.477654  0.111111  0.105263      0.458831  ...
# AAl_12_1.txt            3  0.422713  0.313433  0.214286      0.801784  ...
# AAl_12_2.txt            2  0.480226  0.088235  0.125000      0.500000  ...
# ...                   ...       ...       ...       ...           ...  ...
# VPe_35_1.txt            3  0.379167  0.296703  0.058824      0.171499  ...
# VPe_35_2.txt            1  0.498708  0.134715  0.000000      0.000000  ...
# VPe_36_1.txt            2  0.390374  0.219178  0.062500      0.176777  ...
# AAl_14_2.txt            1  0.442815  0.099338  0.161290      0.635001  ...
# KKo_24_1.txt            3  0.495614  0.026549  0.055556      0.166667  ...
#
#               num_pres_sing  num_pres_plur  num_past_part  num_past_simple  \
# name
# AAl_1_1.txt               9              0              8                2
# AAl_1_2.txt               9              0              8                1
# AAl_11_2.txt             12              0              4                9
# AAl_12_1.txt              8              0             13                4
# AAl_12_2.txt             12              0              5                4
# ...                     ...            ...            ...              ...
# VPe_35_1.txt              1              0              5                9
# VPe_35_2.txt              2              0              1                6
# VPe_36_1.txt              8              0              8                2
# AAl_14_2.txt             12              0              6                5
# KKo_24_1.txt              1              0              4                2
#
#               num_misspelled_tokens  punct_mistakes_pp  \
# name
# AAl_1_1.txt                       3                  0
# AAl_1_2.txt                       2                  0
# AAl_11_2.txt                      1                  0
# AAl_12_1.txt                      3                  0
# AAl_12_2.txt                      3                  1
# ...                             ...                ...
# VPe_35_1.txt                      1                  0
# VPe_35_2.txt                      3                  0
# VPe_36_1.txt                      3                  0
# AAl_14_2.txt                      3                  0
# KKo_24_1.txt                      2                  2
#
#               punct_mistakes_because  punct_mistakes_but  \
# name
# AAl_1_1.txt                        0                   1
# AAl_1_2.txt                        0                   4
# AAl_11_2.txt                       0                   2
# AAl_12_1.txt                       0                   0
# AAl_12_2.txt                       1                   1
# ...                              ...                 ...
# VPe_35_1.txt                       0                   0
# VPe_35_2.txt                       0                   0
# VPe_36_1.txt                       1                   3
# AAl_14_2.txt                       0                   0
# KKo_24_1.txt                       0                   1
#
#               punct_mistakes_compare   CEFR
# name
# AAl_1_1.txt                        0  B1-B2
# AAl_1_2.txt                        0     B1
# AAl_11_2.txt                       1     B1
# AAl_12_1.txt                       0     B1
# AAl_12_2.txt                       0     B1
# ...                              ...    ...
# VPe_35_1.txt                       0     B1
# VPe_35_2.txt                       0     B1
# VPe_36_1.txt                       0  A2-B1
# AAl_14_2.txt                       0  B1-B2
# KKo_24_1.txt                       0     B2
#
# [1170 rows x 64 columns]

# %%
# query('CEFR=="A2-B1").text.iloc[any number]
# query('CEFR=="B1-B2").text.iloc[any number]
# query('CEFR=="B2-C1").text.iloc[any number]

levels.assign(text=pd.DataFrame(txt.values(), index=txt.keys()))[['CEFR', 'text']].query('CEFR=="B2-C1"').text.iloc[0]
# Out:
# 'The table compares the number of people in age from 18 to 65 working in certain sectors in the UK in 1998 and 2006. The number of people working in technology has rapidly increased in each age group, especially in the youngest group of respondents in age from 18 to 25. In opposite, the sphere of building is not so popular as technology: they lost people in each age group. The sphere of hotels & catering became more attractive for people older 26 years: the number of people in this sphere decrease only in the youngest group of respondents. And in final group of people working in education, situation is not good: only people in age from 26 to 45 think that that sphere is perspective and workable; in other age groups numbers of people rapidly decrease.'
